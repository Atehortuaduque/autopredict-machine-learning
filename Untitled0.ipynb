# %% [markdown]
# <a href="https://colab.research.google.com/github/Atehortuaduque/autopredict-machine-learning/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# IMPORTS

# %%
import os
import gc
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import *


import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# kaggle datasets download -d nehalbirla/vehicle-dataset-from-cardekho

# %%
# !gdown https://drive.google.com/file/d/1O9I2Q3zKxJIGKTtVzOO7sX-q3NSgVcT7/view?usp=share_link
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/parse_url.py:35: UserWarning: You specified a Google Drive link that is not the correct link to download a file. You might want to try `--fuzzy` option or the following url: https://drive.google.com/uc?id=1O9I2Q3zKxJIGKTtVzOO7sX-q3NSgVcT7
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/file/d/1O9I2Q3zKxJIGKTtVzOO7sX-q3NSgVcT7/view?usp=share_link
# To: /content/view?usp=share_link
# 80.3kB [00:00, 36.6MB/s]

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
data = pd.read_csv('/content/gdrive/MyDrive/Car details v3.csv')

# %% [markdown]
# # Preprocesamiento

# %%
data.head(10)
# Out:
#                                    name  year  selling_price  km_driven  \
# 0                Maruti Swift Dzire VDI  2014         450000     145500
# 1          Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2              Honda City 2017-2020 EXi  2006         158000     140000
# 3             Hyundai i20 Sportz Diesel  2010         225000     127000
# 4                Maruti Swift VXI BSIII  2007         130000     120000
# 5         Hyundai Xcent 1.2 VTVT E Plus  2017         440000      45000
# 6          Maruti Wagon R LXI DUO BSIII  2007          96000     175000
# 7                    Maruti 800 DX BSII  2001          45000       5000
# 8                      Toyota Etios VXD  2011         350000      90000
# 9  Ford Figo Diesel Celebration Edition  2013         200000     169000
#
#      fuel seller_type transmission         owner     mileage   engine  \
# 0  Diesel  Individual       Manual   First Owner   23.4 kmpl  1248 CC
# 1  Diesel  Individual       Manual  Second Owner  21.14 kmpl  1498 CC
# 2  Petrol  Individual       Manual   Third Owner   17.7 kmpl  1497 CC
# 3  Diesel  Individual       Manual   First Owner   23.0 kmpl  1396 CC
# 4  Petrol  Individual       Manual   First Owner   16.1 kmpl  1298 CC
# 5  Petrol  Individual       Manual   First Owner  20.14 kmpl  1197 CC
# 6     LPG  Individual       Manual   First Owner  17.3 km/kg  1061 CC
# 7  Petrol  Individual       Manual  Second Owner   16.1 kmpl   796 CC
# 8  Diesel  Individual       Manual   First Owner  23.59 kmpl  1364 CC
# 9  Diesel  Individual       Manual   First Owner   20.0 kmpl  1399 CC
#
#     max_power                    torque  seats
# 0      74 bhp            190Nm@ 2000rpm    5.0
# 1  103.52 bhp       250Nm@ 1500-2500rpm    5.0
# 2      78 bhp     12.7@ 2,700(kgm@ rpm)    5.0
# 3      90 bhp  22.4 kgm at 1750-2750rpm    5.0
# 4    88.2 bhp     11.5@ 4,500(kgm@ rpm)    5.0
# 5   81.86 bhp         113.75nm@ 4000rpm    5.0
# 6    57.5 bhp      7.8@ 4,500(kgm@ rpm)    5.0
# 7      37 bhp             59Nm@ 2500rpm    4.0
# 8    67.1 bhp       170Nm@ 1800-2400rpm    5.0
# 9    68.1 bhp            160Nm@ 2000rpm    5.0

# %%
data_rows, data_cols = data.shape
print(f'There are {data_rows} rows and {data_cols} columns')
columns = data.columns.tolist()
columns[2], columns[-1] = columns[-1], columns[2]

data = data[columns]
data.head(10)
# Out:
# There are 8128 rows and 13 columns
#                                    name  year  seats  km_driven    fuel  \
# 0                Maruti Swift Dzire VDI  2014    5.0     145500  Diesel
# 1          Skoda Rapid 1.5 TDI Ambition  2014    5.0     120000  Diesel
# 2              Honda City 2017-2020 EXi  2006    5.0     140000  Petrol
# 3             Hyundai i20 Sportz Diesel  2010    5.0     127000  Diesel
# 4                Maruti Swift VXI BSIII  2007    5.0     120000  Petrol
# 5         Hyundai Xcent 1.2 VTVT E Plus  2017    5.0      45000  Petrol
# 6          Maruti Wagon R LXI DUO BSIII  2007    5.0     175000     LPG
# 7                    Maruti 800 DX BSII  2001    4.0       5000  Petrol
# 8                      Toyota Etios VXD  2011    5.0      90000  Diesel
# 9  Ford Figo Diesel Celebration Edition  2013    5.0     169000  Diesel
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
# 5  Individual       Manual   First Owner  20.14 kmpl  1197 CC   81.86 bhp
# 6  Individual       Manual   First Owner  17.3 km/kg  1061 CC    57.5 bhp
# 7  Individual       Manual  Second Owner   16.1 kmpl   796 CC      37 bhp
# 8  Individual       Manual   First Owner  23.59 kmpl  1364 CC    67.1 bhp
# 9  Individual       Manual   First Owner   20.0 kmpl  1399 CC    68.1 bhp
#
#                      torque  selling_price
# 0            190Nm@ 2000rpm         450000
# 1       250Nm@ 1500-2500rpm         370000
# 2     12.7@ 2,700(kgm@ rpm)         158000
# 3  22.4 kgm at 1750-2750rpm         225000
# 4     11.5@ 4,500(kgm@ rpm)         130000
# 5         113.75nm@ 4000rpm         440000
# 6      7.8@ 4,500(kgm@ rpm)          96000
# 7             59Nm@ 2500rpm          45000
# 8       170Nm@ 1800-2400rpm         350000
# 9            160Nm@ 2000rpm         200000

# %%
data.rename(columns={'engine': 'engine(CC)'}, inplace=True)
data.rename(columns={'max_power': 'max_power(BHP)'}, inplace=True)
data.rename(columns={'mileage': 'fuel consuption(kmpl)'}, inplace= True)

# %%
#Solo correr una vez
data.dropna(subset=['engine(CC)'], inplace=True)
data['engine(CC)'] = data['engine(CC)'].str.extract('(\d+)').astype(int)
data.dropna(subset=['max_power(BHP)'], inplace=True)
data['max_power(BHP)'] = data['max_power(BHP)'].str.extract('(\d+)').astype(float)
data.dropna(subset=['fuel consuption(kmpl)'], inplace=True)
data['fuel consuption(kmpl)'] = data['fuel consuption(kmpl)'].str.extract('(\d+)').astype(float)

# %%
data.head(10)
# Out:
#                                    name  year  seats  km_driven    fuel  \
# 0                Maruti Swift Dzire VDI  2014    5.0     145500  Diesel
# 1          Skoda Rapid 1.5 TDI Ambition  2014    5.0     120000  Diesel
# 2              Honda City 2017-2020 EXi  2006    5.0     140000  Petrol
# 3             Hyundai i20 Sportz Diesel  2010    5.0     127000  Diesel
# 4                Maruti Swift VXI BSIII  2007    5.0     120000  Petrol
# 5         Hyundai Xcent 1.2 VTVT E Plus  2017    5.0      45000  Petrol
# 6          Maruti Wagon R LXI DUO BSIII  2007    5.0     175000     LPG
# 7                    Maruti 800 DX BSII  2001    4.0       5000  Petrol
# 8                      Toyota Etios VXD  2011    5.0      90000  Diesel
# 9  Ford Figo Diesel Celebration Edition  2013    5.0     169000  Diesel
#
#   seller_type transmission         owner  fuel consuption(kmpl)  engine(CC)  \
# 0  Individual       Manual   First Owner                   23.0        1248
# 1  Individual       Manual  Second Owner                   21.0        1498
# 2  Individual       Manual   Third Owner                   17.0        1497
# 3  Individual       Manual   First Owner                   23.0        1396
# 4  Individual       Manual   First Owner                   16.0        1298
# 5  Individual       Manual   First Owner                   20.0        1197
# 6  Individual       Manual   First Owner                   17.0        1061
# 7  Individual       Manual  Second Owner                   16.0         796
# 8  Individual       Manual   First Owner                   23.0        1364
# 9  Individual       Manual   First Owner                   20.0        1399
#
#    max_power(BHP)                    torque  selling_price
# 0            74.0            190Nm@ 2000rpm         450000
# 1           103.0       250Nm@ 1500-2500rpm         370000
# 2            78.0     12.7@ 2,700(kgm@ rpm)         158000
# 3            90.0  22.4 kgm at 1750-2750rpm         225000
# 4            88.0     11.5@ 4,500(kgm@ rpm)         130000
# 5            81.0         113.75nm@ 4000rpm         440000
# 6            57.0      7.8@ 4,500(kgm@ rpm)          96000
# 7            37.0             59Nm@ 2500rpm          45000
# 8            67.0       170Nm@ 1800-2400rpm         350000
# 9            68.0            160Nm@ 2000rpm         200000

# %% [markdown]
# # Gráficas

# %%
plt.scatter(data['km_driven'], data['selling_price'])
plt.xlabel('Kilometers Driven')
plt.ylabel('Selling Price')
plt.title('Selling Price vs. Kilometers Driven')
plt.show()

# %%
plt.scatter(data['km_driven'], data['selling_price'])
plt.xlabel('Kilometers Driven')
plt.ylabel('Selling Price')
plt.title('Selling Price vs. Kilometers Driven')
plt.xlim(0, 400000)

plt.show()

# %%
fuel_counts = data['fuel'].value_counts()
plt.bar(fuel_counts.index, fuel_counts.values)
plt.xlabel('Fuel Type')
plt.ylabel('Number of Cars')
plt.title('Number of Cars by Fuel Type')
plt.show()

# %%
sns.boxplot(x='fuel', y='selling_price', data=data)
plt.xlabel('Fuel Type')
plt.ylabel('Selling Price')
plt.title('Selling Price by Fuel Type')
plt.show()

# %%
matrix = data.corr()

sns.heatmap(matrix, annot=True, fmt=".2f")

plt.show()

# %%
sns.scatterplot(data=data, x='year', y='selling_price')
plt.title('Relationship between Selling Price and Year')
plt.xlabel('Year')
plt.ylabel('Selling Price')
plt.show()

# %%
sns.boxplot(data=data, x='transmission', y='selling_price')
plt.title('Relationship between Transmission and Selling Price')
plt.xlabel('Transmission')
plt.ylabel('Selling Price')
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.boxplot(x='owner', y='selling_price', data=data)
plt.xlabel('Owner Type')
plt.ylabel('Selling Price')
plt.title('Selling Price by Owner Type')
plt.show()

# %% [markdown]
# Eliminaremos la columna de torque ya que esta esta relacionada con la columna de potencia de los motores, por lo cual ya tenemos un valor que representa la potencia de los motores, ademas la columna de torque tiene distintos valores lo cual hace dificil su tratamiento de datos

# %%
data.drop(columns=[ "torque"],inplace = True)
data.drop(columns=[ "seller_type"],inplace = True)

# %%
data.head(50)
# Out:
#                                            name  year  seats  km_driven  \
# 0                        Maruti Swift Dzire VDI  2014    5.0     145500
# 1                  Skoda Rapid 1.5 TDI Ambition  2014    5.0     120000
# 2                      Honda City 2017-2020 EXi  2006    5.0     140000
# 3                     Hyundai i20 Sportz Diesel  2010    5.0     127000
# 4                        Maruti Swift VXI BSIII  2007    5.0     120000
# 5                 Hyundai Xcent 1.2 VTVT E Plus  2017    5.0      45000
# 6                  Maruti Wagon R LXI DUO BSIII  2007    5.0     175000
# 7                            Maruti 800 DX BSII  2001    4.0       5000
# 8                              Toyota Etios VXD  2011    5.0      90000
# 9          Ford Figo Diesel Celebration Edition  2013    5.0     169000
# 10              Renault Duster 110PS Diesel RxL  2014    5.0      68000
# 11                                Maruti Zen LX  2005    5.0     100000
# 12                       Maruti Swift Dzire VDi  2009    5.0     140000
# 14                     Maruti Wagon R LXI Minor  2009    5.0      90000
# 15         Mahindra KUV 100 mFALCON G80 K8 5str  2016    5.0      40000
# 16                       Maruti Ertiga SHVS VDI  2016    7.0      70000
# 17                    Hyundai i20 1.4 CRDi Asta  2012    5.0      53000
# 18                               Maruti Alto LX  2002    5.0      80000
# 19          Hyundai i20 2015-2017 Asta 1.4 CRDi  2016    5.0     100000
# 20                 Mahindra Verito 1.5 D4 BSIII  2011    5.0     100000
# 21                         Honda WR-V i-DTEC VX  2017    5.0      50000
# 22                       Maruti Swift Dzire ZDI  2015    5.0      40000
# 23                               Maruti SX4 ZDI  2012    5.0      72000
# 24                      Tata Tigor 2017-2020 XZ  2018    5.0      35000
# 25                      Maruti Baleno Delta 1.2  2016    5.0      45000
# 26                          Maruti Alto 800 LXI  2017    5.0      28000
# 27            Chevrolet Enjoy TCDi LTZ 7 Seater  2013    7.0      70000
# 28                     Maruti Wagon R LXI Minor  2009    5.0     120000
# 29                  Maruti Omni E MPI STD BS IV  2018    8.0      25000
# 30              Maruti Vitara Brezza LDi Option  2017    5.0      70000
# 32                    Maruti Omni 8 Seater BSIV  2012    5.0      35000
# 33               Hyundai i20 1.2 Asta Dual Tone  2018    5.0       2388
# 34                     Maruti Vitara Brezza LDi  2017    5.0      16200
# 35             Maruti Alto 800 CNG LXI Optional  2019    4.0      10000
# 36                   Maruti Alto K10 VXI Airbag  2019    5.0      15000
# 37             Hyundai Verna VTVT 1.6 SX Option  2019    5.0       5000
# 38                                  Datsun GO D  2016    5.0      42000
# 39                 Tata Safari DICOR 2.2 LX 4x2  2011    7.0      60000
# 40                               Maruti 800 Std  2012    4.0      76000
# 41           Jeep Compass 1.4 Limited Plus BSIV  2019    5.0       5000
# 42                         Honda City i VTEC VX  2018    5.0      28900
# 43                              Honda City V MT  2013    5.0      86300
# 44                    Maruti Swift Dzire VXi AT  2018    5.0      23300
# 45                     Maruti Vitara Brezza VDi  2018    5.0      32600
# 46                          Maruti Alto K10 VXI  2018    5.0      10300
# 47                       Toyota Fortuner 4x4 MT  2014    7.0      77000
# 48  Toyota Innova 2.5 G (Diesel) 7 Seater BS IV  2013    7.0      99000
# 49                   Mercedes-Benz B Class B180  2014    5.0      27800
# 50                         Honda Amaze S Diesel  2015    5.0      49800
# 51                  Mitsubishi Pajero Sport 4X4  2013    7.0     151000
#
#       fuel transmission         owner  fuel consuption(kmpl)  engine(CC)  \
# 0   Diesel       Manual   First Owner                   23.0        1248
# 1   Diesel       Manual  Second Owner                   21.0        1498
# 2   Petrol       Manual   Third Owner                   17.0        1497
# 3   Diesel       Manual   First Owner                   23.0        1396
# 4   Petrol       Manual   First Owner                   16.0        1298
# 5   Petrol       Manual   First Owner                   20.0        1197
# 6      LPG       Manual   First Owner                   17.0        1061
# 7   Petrol       Manual  Second Owner                   16.0         796
# 8   Diesel       Manual   First Owner                   23.0        1364
# 9   Diesel       Manual   First Owner                   20.0        1399
# 10  Diesel       Manual  Second Owner                   19.0        1461
# 11  Petrol       Manual  Second Owner                   17.0         993
# 12  Diesel       Manual  Second Owner                   19.0        1248
# 14  Petrol       Manual  Second Owner                   18.0        1061
# 15  Petrol       Manual   First Owner                   18.0        1198
# 16  Diesel       Manual  Second Owner                   24.0        1248
# 17  Diesel       Manual  Second Owner                   23.0        1396
# 18  Petrol       Manual  Second Owner                   19.0         796
# 19  Diesel       Manual   First Owner                   22.0        1396
# 20  Diesel       Manual  Second Owner                   21.0        1461
# 21  Diesel       Manual   First Owner                   25.0        1498
# 22  Diesel       Manual   First Owner                   26.0        1248
# 23  Diesel       Manual   First Owner                   21.0        1248
# 24  Petrol       Manual   First Owner                   20.0        1199
# 25  Petrol       Manual   First Owner                   21.0        1197
# 26  Petrol       Manual   First Owner                   24.0         796
# 27  Diesel       Manual   First Owner                   18.0        1248
# 28  Petrol       Manual   First Owner                   18.0        1061
# 29  Petrol       Manual   First Owner                   16.0         796
# 30  Diesel       Manual   First Owner                   24.0        1248
# 32  Petrol       Manual  Second Owner                   14.0         796
# 33  Petrol       Manual   First Owner                   18.0        1197
# 34  Diesel       Manual   First Owner                   24.0        1248
# 35     CNG       Manual  Second Owner                   33.0         796
# 36  Petrol       Manual   First Owner                   23.0         998
# 37  Petrol       Manual   First Owner                   17.0        1591
# 38  Petrol       Manual   First Owner                   20.0        1198
# 39  Diesel       Manual  Second Owner                   13.0        2179
# 40  Petrol       Manual   First Owner                   16.0         796
# 41  Petrol    Automatic   First Owner                   16.0        1368
# 42  Petrol       Manual   First Owner                   17.0        1497
# 43  Petrol       Manual   First Owner                   16.0        1497
# 44  Petrol    Automatic   First Owner                   18.0        1197
# 45  Diesel       Manual   First Owner                   24.0        1248
# 46  Petrol       Manual   First Owner                   23.0         998
# 47  Diesel       Manual   First Owner                   12.0        2982
# 48  Diesel       Manual   First Owner                   12.0        2494
# 49  Diesel    Automatic  Second Owner                   14.0        2143
# 50  Diesel       Manual   First Owner                   24.0        1498
# 51  Diesel       Manual   First Owner                   13.0        2477
#
#     max_power(BHP)  selling_price
# 0             74.0         450000
# 1            103.0         370000
# 2             78.0         158000
# 3             90.0         225000
# 4             88.0         130000
# 5             81.0         440000
# 6             57.0          96000
# 7             37.0          45000
# 8             67.0         350000
# 9             68.0         200000
# 10           108.0         500000
# 11            60.0          92000
# 12            73.0         280000
# 14            67.0         180000
# 15            82.0         400000
# 16            88.0         778000
# 17            90.0         500000
# 18            46.0         150000
# 19            88.0         680000
# 20            64.0         174000
# 21            98.0         950000
# 22            74.0         525000
# 23            88.0         600000
# 24            83.0         500000
# 25            83.0         575000
# 26            47.0         275000
# 27            73.0         300000
# 28            67.0         220000
# 29            34.0         254999
# 30            88.0         670000
# 32            35.0         150000
# 33            81.0         730000
# 34            88.0         650000
# 35            40.0         330000
# 36            67.0         366000
# 37           121.0        1149000
# 38            67.0         150000
# 39           138.0         425000
# 40            37.0         150000
# 41           160.0        2100000
# 42           117.0         925000
# 43           116.0         425000
# 44            83.0         675000
# 45            88.0         819999
# 46            67.0         390000
# 47           168.0        1500000
# 48           100.0         700000
# 49           120.0        1450000
# 50            98.0         425000
# 51           175.0        1090000

# %%
data = data[data['owner'] != 'Test Drive Car']

# %%
plt.figure(figsize=(10, 8))
sns.boxplot(x='owner', y='selling_price', data=data)
plt.xlabel('Owner Type')
plt.ylabel('Selling Price')
plt.title('Selling Price by Owner Type')
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
data['fuel_encoded'] = label_encoder.fit_transform(data['fuel'])
data['transmission_encoded'] = label_encoder.fit_transform(data['transmission'])
data['owner_encoded'] = label_encoder.fit_transform(data['owner'])

# %%
fuel_encoded_index = data.columns.get_loc('fuel_encoded')

for _ in range(8):
    data.insert(fuel_encoded_index - 1, 'temp', data['fuel_encoded'])
    data.drop('fuel_encoded', axis=1, inplace=True)
    data.rename(columns={'temp': 'fuel_encoded'}, inplace=True)

# %%
transmission_encoded_index = data.columns.get_loc('transmission_encoded')

for _ in range(8):
    data.insert(fuel_encoded_index - 1, 'temp', data['transmission_encoded'])
    data.drop('transmission_encoded', axis=1, inplace=True)
    data.rename(columns={'temp': 'transmission_encoded'}, inplace=True)

# %%
owner_encoded_index = data.columns.get_loc('owner_encoded')

for _ in range(8):
    data.insert(fuel_encoded_index - 1, 'temp', data['owner_encoded'])
    data.drop('owner_encoded', axis=1, inplace=True)
    data.rename(columns={'temp': 'owner_encoded'}, inplace=True)

# %%
data.head(10)
# Out:
#                                    name  year  seats  km_driven    fuel  \
# 0                Maruti Swift Dzire VDI  2014    5.0     145500  Diesel
# 1          Skoda Rapid 1.5 TDI Ambition  2014    5.0     120000  Diesel
# 2              Honda City 2017-2020 EXi  2006    5.0     140000  Petrol
# 3             Hyundai i20 Sportz Diesel  2010    5.0     127000  Diesel
# 4                Maruti Swift VXI BSIII  2007    5.0     120000  Petrol
# 5         Hyundai Xcent 1.2 VTVT E Plus  2017    5.0      45000  Petrol
# 6          Maruti Wagon R LXI DUO BSIII  2007    5.0     175000     LPG
# 7                    Maruti 800 DX BSII  2001    4.0       5000  Petrol
# 8                      Toyota Etios VXD  2011    5.0      90000  Diesel
# 9  Ford Figo Diesel Celebration Edition  2013    5.0     169000  Diesel
#
#   transmission         owner  fuel consuption(kmpl)  engine(CC)  \
# 0       Manual   First Owner                   23.0        1248
# 1       Manual  Second Owner                   21.0        1498
# 2       Manual   Third Owner                   17.0        1497
# 3       Manual   First Owner                   23.0        1396
# 4       Manual   First Owner                   16.0        1298
# 5       Manual   First Owner                   20.0        1197
# 6       Manual   First Owner                   17.0        1061
# 7       Manual  Second Owner                   16.0         796
# 8       Manual   First Owner                   23.0        1364
# 9       Manual   First Owner                   20.0        1399
#
#    max_power(BHP)  owner_encoded  transmission_encoded  fuel_encoded  \
# 0            74.0              0                     1             1
# 1           103.0              2                     1             1
# 2            78.0              3                     1             3
# 3            90.0              0                     1             1
# 4            88.0              0                     1             3
# 5            81.0              0                     1             3
# 6            57.0              0                     1             2
# 7            37.0              2                     1             3
# 8            67.0              0                     1             1
# 9            68.0              0                     1             1
#
#    selling_price
# 0         450000
# 1         370000
# 2         158000
# 3         225000
# 4         130000
# 5         440000
# 6          96000
# 7          45000
# 8         350000
# 9         200000

# %%
X = data.drop(['name','selling_price'],axis=1)
y = data['selling_price']

print(X)
# Out:
#       year  seats  km_driven    fuel transmission                 owner  \
# 0     2014    5.0     145500  Diesel       Manual           First Owner
# 1     2014    5.0     120000  Diesel       Manual          Second Owner
# 2     2006    5.0     140000  Petrol       Manual           Third Owner
# 3     2010    5.0     127000  Diesel       Manual           First Owner
# 4     2007    5.0     120000  Petrol       Manual           First Owner
# ...    ...    ...        ...     ...          ...                   ...
# 8123  2013    5.0     110000  Petrol       Manual           First Owner
# 8124  2007    5.0     119000  Diesel       Manual  Fourth & Above Owner
# 8125  2009    5.0     120000  Diesel       Manual           First Owner
# 8126  2013    5.0      25000  Diesel       Manual           First Owner
# 8127  2013    5.0      25000  Diesel       Manual           First Owner
#
#       fuel consuption(kmpl)  engine(CC)  max_power(BHP)  owner_encoded  \
# 0                      23.0        1248            74.0              0
# 1                      21.0        1498           103.0              2
# 2                      17.0        1497            78.0              3
# 3                      23.0        1396            90.0              0
# 4                      16.0        1298            88.0              0
# ...                     ...         ...             ...            ...
# 8123                   18.0        1197            82.0              0
# 8124                   16.0        1493           110.0              1
# 8125                   19.0        1248            73.0              0
# 8126                   23.0        1396            70.0              0
# 8127                   23.0        1396            70.0              0
#
#       transmission_encoded  fuel_encoded
# 0                        1             1
# 1                        1             1
# 2                        1             3
# 3                        1             1
# 4                        1             3
# ...                    ...           ...
# 8123                     1             3
# 8124                     1             1
# 8125                     1             1
# 8126                     1             1
# 8127                     1             1
#
# [7902 rows x 12 columns]

# %%
print(y)
# Out:
# 0       450000
# 1       370000
# 2       158000
# 3       225000
# 4       130000
#          ...
# 8123    320000
# 8124    135000
# 8125    382000
# 8126    290000
# 8127    290000
# Name: selling_price, Length: 7902, dtype: int64

# %%
data.shape
# Out:
# (7902, 14)

# %% [markdown]
# # GN Bayes

# %%
new_d=data.drop(['name','fuel','selling_price','transmission',"owner"],axis=1)

new_d.dropna(inplace=True)

new_d.head(10)
# Out:
#    year  seats  km_driven  fuel consuption(kmpl)  engine(CC)  max_power(BHP)  \
# 0  2014    5.0     145500                   23.0        1248            74.0
# 1  2014    5.0     120000                   21.0        1498           103.0
# 2  2006    5.0     140000                   17.0        1497            78.0
# 3  2010    5.0     127000                   23.0        1396            90.0
# 4  2007    5.0     120000                   16.0        1298            88.0
# 5  2017    5.0      45000                   20.0        1197            81.0
# 6  2007    5.0     175000                   17.0        1061            57.0
# 7  2001    4.0       5000                   16.0         796            37.0
# 8  2011    5.0      90000                   23.0        1364            67.0
# 9  2013    5.0     169000                   20.0        1399            68.0
#
#    owner_encoded  transmission_encoded  fuel_encoded
# 0              0                     1             1
# 1              2                     1             1
# 2              3                     1             3
# 3              0                     1             1
# 4              0                     1             3
# 5              0                     1             3
# 6              0                     1             2
# 7              2                     1             3
# 8              0                     1             1
# 9              0                     1             1

# %%
X = new_d.values[:,:-1]
y = new_d.values[:,-1]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=21)
from sklearn.naive_bayes import GaussianNB
est = GaussianNB()
est.fit(X_train,y_train)
print(accuracy_score(est.predict(X_test), y_test))

GN_bayes_accuracy = accuracy_score(est.predict(X_test), y_test)
# Out:
# 0.7210626185958254

# %% [markdown]
# # Decision Tree

# %%
new_d=data.drop(['name','fuel','selling_price','transmission',"owner"],axis=1)

new_d.dropna(inplace=True)

new_d.head(10)
# Out:
#    year  seats  km_driven  fuel consuption(kmpl)  engine(CC)  max_power(BHP)  \
# 0  2014    5.0     145500                   23.0        1248            74.0
# 1  2014    5.0     120000                   21.0        1498           103.0
# 2  2006    5.0     140000                   17.0        1497            78.0
# 3  2010    5.0     127000                   23.0        1396            90.0
# 4  2007    5.0     120000                   16.0        1298            88.0
# 5  2017    5.0      45000                   20.0        1197            81.0
# 6  2007    5.0     175000                   17.0        1061            57.0
# 7  2001    4.0       5000                   16.0         796            37.0
# 8  2011    5.0      90000                   23.0        1364            67.0
# 9  2013    5.0     169000                   20.0        1399            68.0
#
#    owner_encoded  transmission_encoded  fuel_encoded
# 0              0                     1             1
# 1              2                     1             1
# 2              3                     1             3
# 3              0                     1             1
# 4              0                     1             3
# 5              0                     1             3
# 6              0                     1             2
# 7              2                     1             3
# 8              0                     1             1
# 9              0                     1             1

# %%
#decision Tree
X = new_d.values[:,:-1]
y = new_d.values[:,-1]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=21)
from sklearn.tree import DecisionTreeClassifier
est = DecisionTreeClassifier(max_depth=2)
est.fit(X_train,y_train)
print(accuracy_score(est.predict(X_test), y_test))

decision_tree_accuracy = accuracy_score(est.predict(X_test), y_test)
# Out:
# 0.8627450980392157

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

X = new_d.values[:, :-1]
y = new_d.values[:, -1]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=21)

max_depth_values = range(1, 11)
accuracy_values = []

for max_depth in max_depth_values:
    est = DecisionTreeClassifier(max_depth=max_depth)
    est.fit(X_train, y_train)

    predictions = est.predict(X_test)

    accuracy = accuracy_score(y_test, predictions)
    accuracy_values.append(accuracy)

plt.plot(max_depth_values, accuracy_values, marker='o')
plt.xlabel('max_depth')
plt.ylabel('Accuracy')
plt.title('Accuracy vs. max_depth')
plt.show()

# %% [markdown]
# # Random Forest

# %%
new_d=data.drop(['name','fuel','selling_price','transmission',"owner"],axis=1)
new_d.dropna(inplace=True)
new_d.head(10)
# Out:
#    year  seats  km_driven  fuel consuption(kmpl)  engine(CC)  max_power(BHP)  \
# 0  2014    5.0     145500                   23.0        1248            74.0
# 1  2014    5.0     120000                   21.0        1498           103.0
# 2  2006    5.0     140000                   17.0        1497            78.0
# 3  2010    5.0     127000                   23.0        1396            90.0
# 4  2007    5.0     120000                   16.0        1298            88.0
# 5  2017    5.0      45000                   20.0        1197            81.0
# 6  2007    5.0     175000                   17.0        1061            57.0
# 7  2001    4.0       5000                   16.0         796            37.0
# 8  2011    5.0      90000                   23.0        1364            67.0
# 9  2013    5.0     169000                   20.0        1399            68.0
#
#    owner_encoded  transmission_encoded  fuel_encoded
# 0              0                     1             1
# 1              2                     1             1
# 2              3                     1             3
# 3              0                     1             1
# 4              0                     1             3
# 5              0                     1             3
# 6              0                     1             2
# 7              2                     1             3
# 8              0                     1             1
# 9              0                     1             1

# %%
X = new_d.values[:,:-1]
y = new_d.values[:,-1]
from sklearn.ensemble import RandomForestClassifier
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=17)

est = RandomForestClassifier()
est.fit(X_train,y_train)
print(accuracy_score(est.predict(X_test), y_test))
accuracy_values=[]
for max_depth in range(1,15):
    est = DecisionTreeClassifier(max_depth=max_depth,criterion="entropy")
    est.fit(X_train, y_train)

    predictions = est.predict(X_test)

    accuracy = accuracy_score(y_test, predictions)
    accuracy_values.append(accuracy)
plt.style.use('seaborn-darkgrid')
plt.plot(range(1,15), accuracy_values, marker='o')
plt.xlabel('max_depth')
plt.ylabel('Accuracy')
plt.title('Accuracy vs. max_depth')
plt.show()

Random_forest_accuracy = accuracy_score(est.predict(X_test), y_test)
# Out:
# 0.9949399114484504

# %%
accuracy_values = []
for n_estimators in range(1, 10):
    est = RandomForestClassifier(n_estimators=n_estimators, max_depth=8, random_state=17)
    est.fit(X_train, y_train)

    predictions = est.predict(X_test)

    accuracy = accuracy_score(y_test, predictions)
    accuracy_values.append(accuracy)
plt.style.use('seaborn-darkgrid')
plt.plot(range(1, 10), accuracy_values, marker='o')
plt.xlabel('n_estimators')
plt.ylabel('Accuracy')
plt.title('Accuracy vs. n_estimators')
plt.show()

# %% [markdown]
# # Support Virtual Machine

# %%
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score
est = SVC()
est.fit(X_train,y_train)
scores = cross_val_score(est, X_train, y_train, cv=24)
print("Accuracy scores:", scores)
print("Average accuracy:", scores.mean())
svm_acc=scores.mean()

plt.plot(range(1, 25), scores, marker='o')
plt.xlabel('Fold')
plt.ylabel('Accuracy')
plt.title('Cross-Validation Accuracy')
plt.show()
# Out:
# Accuracy scores: [0.63257576 0.67045455 0.65151515 0.63257576 0.65151515 0.60606061
#  0.65909091 0.59090909 0.61977186 0.61977186 0.66920152 0.62357414
#  0.68821293 0.66920152 0.71863118 0.66920152 0.66159696 0.67680608
#  0.66920152 0.6539924  0.63878327 0.68821293 0.68441065 0.65019011]
# Average accuracy: 0.6539773927487806

# %% [markdown]
# # Regresión Lineal

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics
X = new_d[["km_driven", "year", "engine(CC)", "max_power(BHP)","fuel_encoded","owner_encoded"]]
data.dropna(inplace=True)
y = data["selling_price"]
X_train,X_test,Y_train,Y_test=train_test_split(X,y,test_size=0.25,random_state=23)
lin_reg_model=LinearRegression()
lin_reg_model.fit(X_train,Y_train)
training_data_pred=lin_reg_model.predict(X_train)

error_score=metrics.r2_score(Y_train,training_data_pred)

test_data_prediction=lin_reg_model.predict(X_test)
print("R squared Error : ", error_score)
# Out:
# R squared Error :  0.6496202347847735

# %%
plt.scatter(Y_train, training_data_pred)
plt.xlabel("Real Price")
plt.ylabel("Predicted Price")
plt.title(" Real Prices vs Predicted Prices")
plt.show()

# %%
import matplotlib.pyplot as plt

accuracy_scores = [svm_acc,GN_bayes_accuracy,decision_tree_accuracy,Random_forest_accuracy]
methods = ['SVM','GN_Bayes', 'Decision_Tree', 'Random_Forest']


plt.bar(methods,accuracy_scores, edgecolor='black')


plt.xlabel('Accuracy')
plt.ylabel('Frequency')
plt.title('Accuracy Histogram')
plt.show()
